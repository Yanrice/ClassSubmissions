# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
from pprint import pprint
from api_keys import api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#api_key = api_keys.api_key
# Import api_key form config file
#from config import api_key
# Create a setting object with API key and preferred units 
settings = {"units":"imperial", "appid": api_key}
weather_data = []
#with open
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
units = "imperial"
query_url = url + "appid=" + "&q" 
response = requests.get(query_url)
response_json = response.json
current_weather = owm.get_current("hilo",**settings)
print(f":the first reponse is:{current_weather}.")
#print(cities)
# Out:
# :the first reponse is:{'coord': {'lon': -155.08, 'lat': 19.71}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.44, 'pressure': 1015, 'humidity': 69, 'temp_min': 70, 'temp_max': 82.4}, 'visibility': 16093, 'wind': {'speed': 10.29, 'deg': 110}, 'clouds': {'all': 90}, 'dt': 1566686885, 'sys': {'type': 1, 'id': 7881, 'message': 0.0075, 'country': 'US', 'sunrise': 1566662594, 'sunset': 1566708153}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}.

# %%
 url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
# set up list to hold reaponse info

name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0 
print(f"Start city count!")
print(f"~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
for city in cities:
    try: 
        url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
        units = "imperial"
        query_url = url + "appid=" + "&q" 
        response = requests.get(query_url)
        response_json = response.json()
        response = requests.get(f"{url}&q={city}").json()
        name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        count = count + 1
        print(f"\n\ncity number: {count} | City name: {city}")
        print(url)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        
    except KeyError:
        print("not found. moving along...")
# Out:
# Start city count!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 1 | City name: padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 2 | City name: kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 3 | City name: alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 4 | City name: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
# not found. moving along...
# not found. moving along...
#
#
# city number: 5 | City name: yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 6 | City name: saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 7 | City name: vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 8 | City name: albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 9 | City name: niny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 10 | City name: dangriga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 11 | City name: provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 12 | City name: yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 13 | City name: mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 14 | City name: ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 15 | City name: mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 16 | City name: hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 17 | City name: nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 18 | City name: barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 19 | City name: bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 20 | City name: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 21 | City name: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 22 | City name: east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 23 | City name: roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 24 | City name: cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 25 | City name: rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 26 | City name: malaya vishera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 27 | City name: punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 28 | City name: dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 29 | City name: mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 30 | City name: castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 31 | City name: ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 32 | City name: tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 33 | City name: ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# city number: 34 | City name: port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 35 | City name: balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 36 | City name: kanniyakumari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 37 | City name: bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 38 | City name: hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 39 | City name: iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 40 | City name: saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 41 | City name: tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 42 | City name: turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 43 | City name: soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 44 | City name: carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 45 | City name: yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 46 | City name: kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 47 | City name: muncar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 48 | City name: tangzhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 49 | City name: quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 50 | City name: busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 51 | City name: khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 52 | City name: trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 53 | City name: falam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 54 | City name: thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 55 | City name: norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 56 | City name: gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 57 | City name: port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 58 | City name: hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 59 | City name: stutterheim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 60 | City name: poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 61 | City name: vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 62 | City name: zabid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 63 | City name: kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 64 | City name: goya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 65 | City name: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 66 | City name: los lunas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 67 | City name: karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# city number: 68 | City name: avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 69 | City name: ormara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 70 | City name: paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 71 | City name: sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 72 | City name: kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 73 | City name: babu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 74 | City name: atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 75 | City name: baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 76 | City name: fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 77 | City name: torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 78 | City name: gazojak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 79 | City name: sabirabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 80 | City name: fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 81 | City name: airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 82 | City name: cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 83 | City name: aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 84 | City name: saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 85 | City name: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 86 | City name: xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 87 | City name: cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 88 | City name: pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 89 | City name: hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 90 | City name: ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 91 | City name: biskamzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 92 | City name: tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 93 | City name: ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 94 | City name: santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 95 | City name: talisay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 96 | City name: constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 97 | City name: muroran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 98 | City name: zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 99 | City name: challans
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 100 | City name: sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 101 | City name: ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# city number: 102 | City name: otjimbingwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 103 | City name: bassar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 104 | City name: victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 105 | City name: vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 106 | City name: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 107 | City name: pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 108 | City name: pelym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 109 | City name: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 110 | City name: yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 111 | City name: banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 112 | City name: georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 113 | City name: butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 114 | City name: tome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 115 | City name: kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 116 | City name: inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 117 | City name: golden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 118 | City name: saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 119 | City name: allapalli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 120 | City name: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 121 | City name: saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 122 | City name: ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 123 | City name: znamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 124 | City name: saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 125 | City name: kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 126 | City name: invermere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 127 | City name: marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 128 | City name: salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 129 | City name: jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 130 | City name: dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 131 | City name: dengzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 132 | City name: baley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 133 | City name: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 134 | City name: haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# not found. moving along...
#
#
# city number: 135 | City name: souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# city number: 136 | City name: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 137 | City name: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 138 | City name: civita castellana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 139 | City name: mahina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 140 | City name: fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 141 | City name: talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# city number: 142 | City name: nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8dd9ac7f766c6541fa6b59a91716f2df
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create empty lists to append the API data into lists 
#weather_data.to_csv('Output_CSV/weather_data.csv')

city_data = pd.DataFrame({
    "City": name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max temp": max_temp,
    "Wind Speed": wind_speed 
})
# Print count list
city_data.count()

# %%
# Export the city data into a .csv.
city_data.to_csv('city_weather.csv', header=True, index=True)

# %%
# Display data frame 
city_data.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create x and y axis 
x_lat = city_data['Lat']
y_temp = city_data['Max temp']
# plot the graph 
plt.scatter(x_lat, y_temp, marker="o", facecolors="blue", edgecolors="black", s=40)

#  graph labels
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Max_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# create x and y axis 
x_lat = city_data['Lat']
y_hum = city_data['Humidity']
# plot the graph  
plt.scatter(x_lat, y_hum,marker="o", facecolors="blue", edgecolors="black", s=40)

# graph labels
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# Show plot
plt.show

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# create x and y axis 
x_lat = city_data['Lat']
y_cloud = city_data['Cloudiness']
# plot the graph  
plt.scatter(x_lat, y_cloud , marker="o", facecolors="blue", edgecolors="black", s=45)

#  graph labels
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# create x and y axis 
x_lat = city_data['Lat']
y_wind = city_data['Wind Speed']
# plot the graph  
plt.scatter(x_lat, y_wind, marker="o", facecolors="blue", edgecolors="black", s=45)
# #  graph labels
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Wind_Speed.png")

# Show plot
plt.show()
